# %%
# !git clone https://github.com/alchemi5t/AUM-cola-check.git
# Out:
# Cloning into 'AUM-cola-check'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 28 (delta 8), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (28/28), done.

# %%
# !pip install aum
# !pip install transformers
# !pip install nlp
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 66.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 21.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 59 kB 9.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 1.7 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 71.0 MB/s
# ...
#      |████████████████████████████████| 290 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 55.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 74.9 MB/s
# ...
#      |████████████████████████████████| 160 kB 71.0 MB/s
# ...
#      |████████████████████████████████| 192 kB 71.1 MB/s
# ...

# %%
# %cd /content/AUM-cola-check/code/
# Out:
# /content/AUM-cola-check/code

# %%
# !mv ../../AUM-cola-check/ ../../AUM-main

# %%
# !rm -r CoLA*
# !wget https://dl.fbaipublicfiles.com/glue/data/CoLA.zip
# !unzip CoLA.zip
# Out:
# rm: cannot remove 'CoLA*': No such file or directory
# --2021-11-10 19:36:39--  https://dl.fbaipublicfiles.com/glue/data/CoLA.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 376971 (368K) [application/zip]
# Saving to: ‘CoLA.zip’
#
# CoLA.zip            100%[===================>] 368.14K  1.05MB/s    in 0.3s
#
# 2021-11-10 19:36:40 (1.05 MB/s) - ‘CoLA.zip’ saved [376971/376971]
#
# Archive:  CoLA.zip
#    creating: CoLA/
#   inflating: CoLA/dev.tsv
#    creating: CoLA/original/
#    creating: CoLA/original/raw/
#   inflating: CoLA/original/raw/in_domain_dev.tsv
#   inflating: CoLA/original/raw/in_domain_train.tsv
#   inflating: CoLA/original/raw/out_of_domain_dev.tsv
#    creating: CoLA/original/tokenized/
#   inflating: CoLA/original/tokenized/in_domain_dev.tsv
# ...

# %%
# !python Main.py --section distilBERT_CoLA
# Out:
# For: seed - 100 noise - 0.0
# Downloading: 100% 226k/226k [00:00<00:00, 2.29MB/s]
# Downloading: 100% 455k/455k [00:00<00:00, 4.35MB/s]
# Downloading: 100% 28.0/28.0 [00:00<00:00, 39.2kB/s]
# Downloading: 100% 483/483 [00:00<00:00, 833kB/s]
# Downloading: 100% 256M/256M [00:11<00:00, 23.8MB/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
import pandas as pd
a = pd.read_csv("/content/AUM-main/code/AUM/full_aum_records.csv")

# %%
a[a["sample_id"] == 390] #He I often sees Mary.
# Out:
#       sample_id  num_measurements  target_logit  ...  other_val    margin       aum
# 2340        390                 1             1  ...   0.092033 -0.126169 -0.126169
# 2341        390                 2             1  ...   0.519390 -0.945398 -0.535783
# 2342        390                 3             1  ...   0.558796 -1.021338 -0.697635
# 2343        390                 4             1  ...   1.234879 -2.413453 -1.126589
# 2344        390                 5             1  ...   1.099956 -2.118113 -1.324894
# 2345        390                 6             1  ...   0.532205 -0.999813 -1.270714
#
# [6 rows x 8 columns]

# %%
a[a["sample_id"] == 5766] # Heidi believes any description of herself.
# Out:
#        sample_id  num_measurements  target_logit  ...  other_val    margin       aum
# 34596       5766                 1             2  ...   0.445276 -0.513382 -0.513382
# 34597       5766                 2             2  ...   0.241234 -0.204986 -0.359184
# 34598       5766                 3             2  ...   0.663556 -0.720634 -0.479667
# 34599       5766                 4             2  ...   1.178378 -1.113183 -0.638046
# 34600       5766                 5             2  ...   1.415665 -1.363280 -0.783093
# 34601       5766                 6             2  ...   2.253354 -2.562761 -1.079704
#
# [6 rows x 8 columns]

# %%
a[a["sample_id"] == 2801] # Paula hit the sticks.
# Out:
#        sample_id  num_measurements  target_logit  ...  other_val    margin       aum
# 16806       2801                 1             0  ...   0.435104 -0.780377 -0.780377
# 16807       2801                 2             0  ...   1.319458 -2.881145 -1.830761
# 16808       2801                 3             0  ...   0.785963 -1.546701 -1.736074
# 16809       2801                 4             0  ...   0.696873 -1.540228 -1.687113
# 16810       2801                 5             0  ...   0.878547 -0.970831 -1.543856
# 16811       2801                 6             0  ...   0.522206  0.618854 -1.183405
#
# [6 rows x 8 columns]

# %%
a[a["sample_id"] == 1522] # That the sun is out was obvious.
# Out:
#       sample_id  num_measurements  target_logit  ...  other_val    margin       aum
# 9132       1522                 1             0  ...   0.312654 -0.690571 -0.690571
# 9133       1522                 2             0  ...  -0.072838  0.340568 -0.175001
# 9134       1522                 3             0  ...   0.769879 -1.899011 -0.749671
# 9135       1522                 4             0  ...   0.670680 -2.008924 -1.064484
# 9136       1522                 5             0  ...   0.595553 -1.075380 -1.066664
# 9137       1522                 6             0  ...   0.436282  0.226892 -0.851071
#
# [6 rows x 8 columns]

# %%
a[a["sample_id"] == 8332] # I wanted Jimmy for to come with me.
# Out:
#        sample_id  num_measurements  target_logit  ...  other_val    margin       aum
# 49992       8332                 1             1  ...  -0.008687  0.445459  0.445459
# 49993       8332                 2             1  ...   0.261390 -0.483645 -0.019093
# 49994       8332                 3             1  ...   0.705792 -1.264820 -0.434336
# 49995       8332                 4             1  ...   1.114132 -2.146055 -0.862265
# 49996       8332                 5             1  ...   0.898410 -1.813932 -1.052599
# 49997       8332                 6             1  ...   0.889920 -2.191947 -1.242490
#
# [6 rows x 8 columns]
